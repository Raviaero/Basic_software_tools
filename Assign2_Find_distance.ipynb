# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('frm_locations.csv')

# %%
df.head()
# Out:
#                              frm_id                       date   latitude  \
# 0  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-22T12:48:34+05:30  19.064700
# 1  b96dc9bb896edad075da09f0c4e9098c  2020-07-20T09:51:41+05:30  28.460339
# 2  84a9427621fe0669fbacbe6d7dc25b3d  2020-07-23T03:02:22+05:30  19.181723
# 3  b96dc9bb896edad075da09f0c4e9098c  2020-07-21T21:19:46+05:30  28.452883
# 4  b96dc9bb896edad075da09f0c4e9098c  2020-07-22T22:49:44+05:30  28.460367
#
#    longitude
# 0  72.892420
# 1  77.016685
# 2  72.999130
# 3  77.076515
# 4  77.016685

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
df[['date','time']] = df.date.str.split('T',expand = True)

# %%
df.rename(columns = {'latitude':'start_latitude',
                     'longitude':'start_longitude'},
         inplace = True)
df.sort_values(by = ['frm_id','date','time'],
               inplace = True)

# %%
df =  df[['frm_id','date','time','start_latitude','start_longitude']]

# %%
df.head()
# Out:
#                                 frm_id        date            time  \
# 2966  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:24:31+05:30
# 2462  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:24:36+05:30
# 2867  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:39:36+05:30
# 2521  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:54:33+05:30
# 2931  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  01:09:36+05:30
#
#       start_latitude  start_longitude
# 2966       18.964563        72.844330
# 2462       19.064554        72.892650
# 2867       19.064680        72.892395
# 2521       19.064680        72.892395
# 2931       19.064680        72.892395

# %%
def find_distance(df):
    # Finding end points
    df['end_latitude'] = df['start_latitude'].shift(periods = -1)
    df['end_longitude'] = df['start_longitude'].shift(periods = -1)
    df['end_latitude'].iat[-1] = df['start_latitude'].iloc[-1] 
    df['end_longitude'].iat[-1] = df['start_longitude'].iloc[-1]
    
    #change on angles in radians
    df['delta_latitude[rad]'] = 0.5*(np.pi/180)*(df['end_latitude']
                                            -df['start_latitude']).apply(np.abs)
    df['delta_longitude[rad]'] = 0.5*(np.pi/180)*(df['end_longitude']
                                             -df['start_longitude']).apply(np.abs)
    
    #finding length of each path
    radius_of_earth = 6371 # in kms
    df['chord_length'] = 2*radius_of_earth*(((
                            df['delta_latitude[rad]'].apply(np.sin)**2
                            +((np.pi/180)*df['start_latitude']).apply(np.cos)
                            *((np.pi/180)*df['end_latitude']).apply(np.cos)
                            *df['delta_longitude[rad]'].apply(np.sin)**2)
                             .apply(np.sqrt)).apply(np.arcsin))
    
    
    return df

# %%
df = df.groupby(['frm_id','date']).apply(find_distance).reset_index()

# %%
df.head()
# Out:
#    index                            frm_id        date            time  \
# 0   2966  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:24:31+05:30
# 1   2462  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:24:36+05:30
# 2   2867  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:39:36+05:30
# 3   2521  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  00:54:33+05:30
# 4   2931  753aa4603d9f9f250ffe7f63e77bac1c  2020-07-20  01:09:36+05:30
#
#    start_latitude  start_longitude  end_latitude  end_longitude  \
# 0       18.964563        72.844330     19.064554      72.892650
# 1       19.064554        72.892650     19.064680      72.892395
# 2       19.064680        72.892395     19.064680      72.892395
# 3       19.064680        72.892395     19.064680      72.892395
# 4       19.064680        72.892395     19.064684      72.892400
#
#    delta_latitude[rad]  delta_longitude[rad]  chord_length
# 0         8.725861e-04          4.216715e-04     12.223948
# 1         1.099557e-06          2.225295e-06      0.030241
# 2         0.000000e+00          0.000000e+00      0.000000
# 3         0.000000e+00          0.000000e+00      0.000000
# 4         3.490659e-08          4.363323e-08      0.000688

# %%
df_distance = df.loc[:,['frm_id','date','chord_length']]

# %%
#filtering out random points
lower_bound = 0.001 
upper_bound = 20
df_distance = df_distance[(df_distance['chord_length'] >= lower_bound)&(df_distance['chord_length'] <= upper_bound)]

# %%
#finding total distance travelled
df_distance = df_distance.groupby(['frm_id','date']).sum()

# %%
df_distance = df_distance.reset_index()

# %%
df_distance.rename(columns = {'chord_length':'Total_distance'},inplace = True)

# %%
dist_frame = df_distance.pivot(index = 'frm_id',columns = 'date', values = 'Total_distance' )

# %%
dist_frame
# Out:
# date                              2020-07-20  2020-07-21  2020-07-22  \
# frm_id
# 753aa4603d9f9f250ffe7f63e77bac1c  127.660430    0.866403    0.528330
# 84a9427621fe0669fbacbe6d7dc25b3d    0.663759  132.138270   14.112246
# ab472ecc61608f512e4b1d4c2b49e8f8    6.875255    8.042475   34.220689
# b96dc9bb896edad075da09f0c4e9098c  102.070845   63.106936   23.215201
# e89712a6621c47b9485e0b06841f809f   88.732890  431.035290  123.737458
# f9a1994416db0f2255ef187f87c38638    0.044168    0.283884    0.491250
#
# date                              2020-07-23  2020-07-24
# frm_id
# 753aa4603d9f9f250ffe7f63e77bac1c    0.382577    0.445485
# 84a9427621fe0669fbacbe6d7dc25b3d    0.620410    0.302441
# ab472ecc61608f512e4b1d4c2b49e8f8   70.884598   40.306332
# b96dc9bb896edad075da09f0c4e9098c   35.409500   14.050621
# e89712a6621c47b9485e0b06841f809f  120.577718  252.561389
# f9a1994416db0f2255ef187f87c38638    0.550873    0.557124
